# %% [markdown]
# # Roll number : 235229116
# ## Name : Mohamed Zaheerudeen
# ### LAB-1

# %% [markdown]
# Question1.
# Write a program for Password Management System
#  File creation: Ask user to enter N user names and their passwords. Store usernames
# and passwords into a file named “loginfile.txt”. Store each user and password in one
# line.
#  File Processing: Write a program that opens your “security.txt” file and reads
# usernames and passwords from it. Store user names in one list and passwords in
# another lists.
#  Querying: ask user to enter user name and password for verification. If they match
# the values stored in the lists, print a message “Login Successful”. Otherwise print a
# message “Login Failed, try again”.

# %%
with open('loginfile.txt','w') as loginfile:
    while True:
            usr=input('Enter a user name')
            pas=input('Enter a password')
            line=usr+' '+ pas+' '+'\n'
            loginfile.write(line)
            y=input('do you want quit (type q)')
            if(y=='q'):
                 break

    
usrlist=[]
paslist=[]
with open('loginfile.txt','r') as old , open('security.txt','w') as new :
        for line in old:
            new.write(line)
with open('security.txt','r') as new:
        for line in new:
            print(line)
            x=line.split(' ')
            usrlist.append(x[0])
            paslist.append(x[1])
print(usrlist,paslist)
print('verification')
u=input("enter your user name")
p=input("enter your password")
if u in usrlist:
    index=usrlist.index(u)
    print(paslist[index])
    if p ==paslist[index]:
            print("login sucessfully")
    else:
            print("password is incorrect")
else:
        print("user name not founded")
# Out:
# Enter a user namesanthiya
# Enter a password123
# do you want quit (type q).
# Enter a user nameswetha
# Enter a password234
# do you want quit (type q)mandhu
# Enter a user name456
# Enter a passwordsrinu
# do you want quit (type q)178
# Enter a user namemandhu
# Enter a password23
# do you want quit (type q)q
# santhiya 123
#
# swetha 234
#
# 456 srinu
#
# mandhu 23
#
# ['santhiya', 'swetha', '456', 'mandhu'] ['123', '234', 'srinu', '23']
# verification
# enter your user name456
# enter your passwordsrinu
# srinu
# login sucessfully

# %% [markdown]
# Question2.
# Write a program for Student Performance Analysis
# ∙ Create a text file, 'marks.txt', with N marks as floating point numbers. Open the file,  read marks from it and compute and print the highest mark.
# ∙ If the user runs the program more than once you should not overwrite the previous  text file – simply append the marks to the end of the file.
# ∙ Modify the above program so that it also prints Top-3 highest marks (Note: you may  need to use list concept)

# %%
with open('mark.txt','a') as m:
    while True:
        print("Enter a mark in float if you want to quite type(-1)")
        mark=float(input(">"))
        if(mark==-1):
            break
        string=str(mark)+" "
        m.write(string)
with open('mark.txt','r') as find:
    for i in find:
        marks=i.split(' ')
        marks.pop()
        
print(marks)
marklist=[]
for i in marks:
    n=eval(i)
    marklist.append(n) 
print(marklist)
maxx=[]
minn=[]
l=marklist
for i in range(3):
    temp=max(l)
    maxx.append(temp)
    l.remove(temp)
for i in range(3):
    temp=min(l)
    minn.append(temp)
    l.remove(temp)
print("max: ",maxx,"\nmin: ",minn)
# Out:
# Enter a mark in float if you want to quite type(-1)
# >98
# Enter a mark in float if you want to quite type(-1)
# >90.7
# Enter a mark in float if you want to quite type(-1)
# >-1
# ['98.4', '68.5', '75.8', '86.9', '85.3', '97.5', '83.6', '86.85', '98.7', '98.9', '78.0', '67.9', '76.0', '98.0', '90.7']
# [98.4, 68.5, 75.8, 86.9, 85.3, 97.5, 83.6, 86.85, 98.7, 98.9, 78.0, 67.9, 76.0, 98.0, 90.7]
# max:  [98.9, 98.7, 98.4]
# min:  [67.9, 68.5, 75.8]

# %% [markdown]
# Question3.
# Write a program for Stock Price Analysis
#  File Creation: Continually prompt a user for stock name, followed by price values for
# 5 days. Each row indicates stock name and daily prices of one stock. Store these
# values in a text file called “stock-prices.txt”. Open the file in Append Mode. Prompt
# message “Do you want to continue? “ and stop reading values accordingly. Then, you
# can close your file.
#  File Processing: Now, open your file for processing. Print stock name, minimum
# price, maximum price and average price values.
#  You can also print which day stock price was lowest in the week and which day stock
# price was highest. So, modify your print statement to print stock name, minimum
# price & day of minimum price, maximum price & day of maximum price and average
# price values. (Hint: Use enumerate to get index values)

# %%
with open("stock-prices.txt",'a') as  s:
    while True:
        sname=input("Enter a name (quit=q)")
        if(sname=='q'):
            break
        lst=[]
        print("price values for 5 days")
        for i in range(5):
            lst.append(int(input(">")))
        price=str(lst)
        line=sname+'@'+price
        s.write(line)
        s.write('\n')

with open("stock-prices.txt",'r') as  s: 
    for i in s:
        temp=i.split('@')
        a=temp[0]
        sp=eval(temp[1])
        mx=max(sp)
        mn=min(sp)
        avg=sum(sp)/len(sp)
        print("stock name",a)
        print('minium price',mn,' on day',sp.index(mn)+1)
        print('maxium price',mx,' on day',sp.index(mx)+1)
        print('average',avg)
# Out:
# Enter a name (quit=q)happy
# price values for 5 days
# >8898
# >898
# >8099
# >9809
# >897
# Enter a name (quit=q)q
# stock name a
# minium price 1  on day 1
# maxium price 5  on day 5
# average 3.0
# stock name hcl
# minium price 1243  on day 1
# maxium price 441222  on day 4
# average 90049.0
# stock name good day
# minium price 346  on day 1
# maxium price 36444444  on day 4
# average 7983689.0
# stock name SBI
# minium price 2345  on day 2
# maxium price 45525  on day 1
# average 19820.6
# stock name SBI
# minium price 23  on day 2
# maxium price 321  on day 4
# average 130.4
# stock name ICIC
# minium price 42  on day 4
# maxium price 4321  on day 1
# average 1090.4
# stock name Q
# minium price 2  on day 5
# maxium price 123  on day 1
# average 40.2
# stock name happy
# minium price 897  on day 5
# maxium price 9809  on day 4
# average 5720.2

# %% [markdown]
# Question4.
# Write a program for File Explorer
#  Display the contents of
#  Count the number of lines in a text file. (Use splitlines())
#  Count the number of unique words in a file.
#  Find frequency of words in a given file. (Hint: Use Counter object)
#  Show a random line in a file. (Use Random object)

# %%
import random
file=input("Enter a file name with extension(filename.txt) ")

with open('filex.txt','r',encoding='utf-8') as f:
       
        lines=f.read().split('\n') 
        for i in lines: 
            print(i)  #display the content
        
        print("\n\n",len(lines),"lines in this file \n")#display the count lines
        
        wordlist=[]
        for line in lines:
            words=line.split()
            for word in words:
                wordlist.append(word)
        #print(wordlist)# this list contain all words from file
        
        unique_word=list(set(wordlist))#its have unique words
        print("The Countning of unique words in a file is ",len(unique_word),"\n")
        #count of unique words
        #print(unique_word)
        
        count_unique_word=[]#its have counting of unique word
        for i in unique_word:
            x=wordlist.count(i)#counting of unique word
            count_unique_word.append(x)
        higfrq=max(count_unique_word) #have high count
        index=count_unique_word.index(higfrq)#find index 
        
        print("high frequency of words is ' ",unique_word[higfrq]," ' count is",higfrq,"\n")
        
        #Show a random line in a file. (Use Random object)
        print("random line in a file")
        print(random.choice(lines))
# Out:
# Enter a file name with extension(filename.txt) filex.txt
# This life is what you make it.
# No matter what, you're going to mess up sometimes, it's a universal truth.
# But the good part is you get to decide how you're going to mess it up.
# Girls will be your friends - they'll act like it anyway.
# But just remember, some come, some go.
# The ones that stay with you through everything - they're your true best friends. Don't let go of them.
# Also remember, sisters make the best friends in the world.
# As for lovers, well, they'll come and go too.
# And baby, I hate to say it, most of them - actually pretty much all of them are going to break your heart, but you can't give up because if you give up, you'll never find your soulmate.
# You'll never find that half who makes you whole and that goes for everything.
# Just because you fail once, doesn't mean you're gonna fail at everything.
# Keep trying, hold on, and always, always, always believe in yourself, because if you don't, then who will, sweetie? So keep your head high, keep your chin up, and most importantly, keep smiling, because life's a beautiful thing and there's so much to smile about.”
#
#
#  12 lines in this file
#
# The Countning of unique words in a file is  136
#
# high frequency of words is '  what  ' count is 8
#
# random line in a file
# Just because you fail once, doesn't mean you're gonna fail at everything.

# %% [markdown]
# Question5. [File Searcher]. Develop an application in Python to read through the email data
# (“mbox-short.txt”) and when you find line that starts with “From”, you will split the line into
# words using the split function. We are interested in who sent the message, which is the
# second word on the From line: From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008.
# You will parse the From line and print out the second word for each From line, then you will
# also count the number of From (not From:) lines and print out a count at the end

# %%
with open('mbox-short.txt','r') as data:
    lines=data.readlines()
    count=0
    for line in lines:
        if line.lower().startswith("from"):
            count+=1
            words=line.split()
            print(words[1])
    print("there were {} of FROM lines in this file".format(count))
# Out:
# stephen.marquard@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# zqian@umich.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# there were 54 of FROM lines in this file

# %% [markdown]
# Question6. Write a program to read and write CSV files
#  File Creation: Create MS Excel file (“student_marks.csv”) with 5 rows of student
# name, mark1, mark2, mark3, mark4. Use comma to separate each value in a row.
#  File Display: Now, open your CSV file and display the file contents row by row (More
# information at: https://docs.python.org/3/library/csv.html).
#  File Writing: Now, open (“student_marks.csv”) for writing. Ask user to enter name
# followed by 4 marks for one new student and write them onto the file.

# %%
#read
import csv
with open ('studentmark.csv','r') as csvf:
    c=csv.reader(csvf)
    for i in c:
        print(i)
        
#write
with open('studentmark.csv','a') as csvw:
    csvww=csv.writer(csvw)
    newstud=[]
    for i in range(5):
        if(i==0):
            newstud.append(input("Enter a student name  :"))
        else:
            print("Enter a mark",i," ")
            newstud.append(int(input(">")))
    print(newstud)
    csvww.writerow(newstud)
# Out:
# ['student name', 'mark1', 'mark2', 'mark3', 'mark4']
# ['santhiya', '65', '78', '78', '67']
# ['swetha', '78', '75', '98', '89']
# ['mandhu', '87', '86', '76', '78']
# ['eswar', '56', '68', '67', '79']
# ['sayee', '76', '76', '98', '97']
# Enter a student name  :ashish
# Enter a mark 1
# >98
# Enter a mark 2
# >97
# Enter a mark 3
# >96
# Enter a mark 4
# >99
# ['ashish', 98, 97, 96, 99]

# %%
import csv
with open ('studentmark.csv','r') as csvf:
    c=csv.reader(csvf)
    for i in c:
        print(i)
# Out:
# ['student name', 'mark1', 'mark2', 'mark3', 'mark4']
# ['santhiya', '65', '78', '78', '67']
# ['swetha', '78', '75', '98', '89']
# ['mandhu', '87', '86', '76', '78']
# ['eswar', '56', '68', '67', '79']
# ['sayee', '76', '76', '98', '97']
# ['ashish', '98', '97', '96', '99']
# []
