# %% [markdown]
# # Roll number : 235229116
# ## Name : Mohamed Zaheerudeen
# ### LAB-1

# %% [markdown]
# Create a new class called Account.

# %%
class Account:
    def __init__(self, account_number, account_holder, opening_balance, account_type):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = opening_balance
        self.type = account_type
    
    def deposit(self, amount):
        self.balance += amount
        
    def withdraw(self, amount):
        self.balance -= amount
        
    def get_balance(self):
        return self.balance
    
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, {self.type} account = {self.balance:.2f}'

acc1 = Account('123', 'John', 10.05, 'current')
acc2 = Account('345', 'John', 23.55, 'savings')
acc3 = Account('567', 'Phoebe', 12.45, 'investment')

print(acc1)
print(acc2)
print(acc3)

acc1.deposit(23.45)
acc1.withdraw(12.33)

print('balance:', acc1.get_balance())
# Out:
# Account[123] - John, current account = 10.05
# Account[345] - John, savings account = 23.55
# Account[567] - Phoebe, investment account = 12.45
# balance: 21.17

# %% [markdown]
# keep track of number of instanses of account

# %%
class Account:
    instance_count = 0  
    
    def __init__(self, account_number, account_holder, opening_balance, account_type):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = opening_balance
        self.type = account_type
        Account.instance_count += 1  
       
    def deposit(self,amount):
        self.balance+=amount
    def withdraw(self,amount):
        self.balance-=amount
    def get_balance(self):
        return self.balance
    def __str__ (self):
        return 'Account[' +self.account_number +']-' +self.account_holder
        
        
acc1 = Account('123', 'John', 10.05, 'current')
acc2 = Account('345', 'John', 23.55, 'savings')
acc3 = Account('567', 'Phoebe', 12.45, 'investment')
print(acc1)
print(acc2)
print(acc3)

acc1.deposit(23.45)
acc1.withdraw(12.33)

print('balance:', acc1.get_balance())
print('Number of Account instances created:', Account.instance_count)

# %% [markdown]
# Create sub classes for Account class

# %%
class Account:
    instance_count = 0
    
    def __init__(self, account_number, account_holder, opening_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = opening_balance
        Account.instance_count += 1
        
    def deposit(self, amount):
        self.balance += amount
        
    def withdraw(self, amount):
        self.balance -= amount
        
    def get_balance(self):
        return self.balance
    
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, balance = {self.balance:.2f}'

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, overdraft_limit):
        super().__init__(account_number, account_holder, opening_balance)
        self.overdraft_limit = overdraft_limit
        
    def withdraw(self, amount):
        if self.balance - amount >= -self.overdraft_limit:
            super().withdraw(amount)
        else:
            print("Withdrawal would exceed your overdraft limit")
            
    def __str__(self):
        return f'Current Account[{self.account_number}] - {self.account_holder}, balance = {self.balance:.2f}, overdraft limit = {self.overdraft_limit:.2f}'

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, interest_rate):
        super().__init__(account_number, account_holder, opening_balance)
        self.interest_rate = interest_rate
        
    def __str__(self):
        return f'Deposit Account[{self.account_number}] - {self.account_holder}, balance = {self.balance:.2f}, interest rate = {self.interest_rate:.2f}%'

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, investment_type):
        super().__init__(account_number, account_holder, opening_balance)
        self.investment_type = investment_type
        
    def __str__(self):
        return f'Investment Account[{self.account_number}] - {self.account_holder}, balance = {self.balance:.2f}, investment type = {self.investment_type}'

# Test application
acc1 = CurrentAccount('123', 'John', 10.05, 100.0)
acc2 = DepositAccount('345', 'John', 23.55, 0.5)
acc3 = InvestmentAccount('567', 'Phoebe', 12.45, 'high risk')

print(acc1)
print(acc2)
print(acc3)

acc1.deposit(23.45)
acc1.withdraw(12.33)
print('balance:', acc1.get_balance())

acc1.withdraw(300.00)
print('balance:', acc1.get_balance())

# %% [markdown]
# Add Properties to Account class

# %%
class Account:
    instance_count = 0
    
    def __init__(self, account_number, account_holder, opening_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self._balance = opening_balance  # Use an underscore to indicate it's a private attribute
        Account.instance_count += 1
        
    @property
    def balance(self):
        return self._balance
    
    def deposit(self, amount):
        self._balance += amount
        
    def withdraw(self, amount):
        self._balance -= amount
        
    def get_balance(self):
        return self._balance
    
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}'

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, overdraft_limit):
        super().__init__(account_number, account_holder, opening_balance)
        self.overdraft_limit = overdraft_limit
        
    def withdraw(self, amount):
        if self._balance - amount >= -self.overdraft_limit:
            super().withdraw(amount)
        else:
            print("Withdrawal would exceed your overdraft limit")
            
    def __str__(self):
        return f'Current Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, overdraft limit = {self.overdraft_limit:.2f}'

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, interest_rate):
        super().__init__(account_number, account_holder, opening_balance)
        self.interest_rate = interest_rate
        
    def __str__(self):
        return f'Deposit Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, interest rate = {self.interest_rate:.2f}%'

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, investment_type):
        super().__init__(account_number, account_holder, opening_balance)
        self.investment_type = investment_type
        
    def __str__(self):
        return f'Investment Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, investment type = {self.investment_type}'

# Test application
acc1 = CurrentAccount('123', 'John', 10.05, 100.0)
acc2 = DepositAccount('345', 'John', 23.55, 0.5)
acc3 = InvestmentAccount('567', 'Phoebe', 12.45, 'high risk')

print(acc1)
print(acc2)
print(acc3)

acc1.deposit(23.45)
acc1.withdraw(12.33)
print('balance:', acc1.balance)
print('Number of Account instances created:', Account.instance_count)
print('balance:', acc1.balance)
acc1.withdraw(300.00)
print('balance:', acc1.balance)

# %%
Add Error Handling routines

# %%
class AmountError(Exception):
    def __init__(self, account, message):
        self.account = account
        self.message = message
        super().__init__(self.message)

class BalanceError(Exception):
    def __init__(self, account, message):
        self.account = account
        self.message = message
        super().__init__(self.message)

class Account:
    instance_count = 0
    
    def __init__(self, account_number, account_holder, opening_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self._balance = opening_balance
        Account.instance_count += 1
        
    @property
    def balance(self):
        return self._balance
    
    def deposit(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot deposit negative amounts")
        self._balance += amount
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        self._balance -= amount
        
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}'

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, overdraft_limit):
        super().__init__(account_number, account_holder, opening_balance)
        self.overdraft_limit = overdraft_limit
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        if self._balance - amount >= -self.overdraft_limit:
            super().withdraw(amount)
        else:
            raise BalanceError(self, "Withdrawal would exceed your overdraft limit")
            
    def __str__(self):
        return f'Current Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, overdraft limit = {self.overdraft_limit:.2f}'

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, interest_rate):
        super().__init__(account_number, account_holder, opening_balance)
        self.interest_rate = interest_rate
        
    def __str__(self):
        return f'Deposit Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, interest rate = {self.interest_rate:.2f}%'

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, investment_type):
        super().__init__(account_number, account_holder, opening_balance)
        self.investment_type = investment_type
        
    def __str__(self):
        return f'Investment Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, investment type = {self.investment_type}'

# Test application
acc1 = CurrentAccount('123', 'John', 10.05, 100.0)
acc2 = DepositAccount('345', 'John', 23.55, 0.5)
acc3 = InvestmentAccount('567', 'Phoebe', 12.45, 'high risk')

try:
    print('balance:', acc1.balance)
    acc1.withdraw(300.00)
    print('balance:', acc1.balance)
except BalanceError as e:
    print('Handling BalanceError:', e)

try:
    acc1.deposit(-1)
except AmountError as e:
    print(e)

try:
    acc1.withdraw(300.00)
except BalanceError as e:
    print('Handling BalanceError:', e)
# Out:
# balance: 10.05
# Handling BalanceError: Withdrawal would exceed your overdraft limit
# Cannot deposit negative amounts
# Handling BalanceError: Withdrawal would exceed your overdraft limit

# %% [markdown]
# Package all classes into a separate module

# %%
class AmountError(Exception):
    def __init__(self, account, message):
        self.account = account
        self.message = message
        super().__init__(self.message)

class BalanceError(Exception):
    def __init__(self, account, message):
        self.account = account
        self.message = message
        super().__init__(self.message)

class Account:
    instance_count = 0
    
    def __init__(self, account_number, account_holder, opening_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self._balance = opening_balance
        Account.instance_count += 1
        
    @property
    def balance(self):
        return self._balance
    
    def deposit(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot deposit negative amounts")
        self._balance += amount
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        self._balance -= amount
        
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}'

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, overdraft_limit):
        super().__init__(account_number, account_holder, opening_balance)
        self.overdraft_limit = overdraft_limit
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        if self._balance - amount >= -self.overdraft_limit:
            super().withdraw(amount)
        else:
            raise BalanceError(self, "Withdrawal would exceed your overdraft limit")
            
    def __str__(self):
        return f'Current Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, overdraft limit = {self.overdraft_limit:.2f}'

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, interest_rate):
        super().__init__(account_number, account_holder, opening_balance)
        self.interest_rate = interest_rate
        
    def __str__(self):
        return f'Deposit Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, interest rate = {self.interest_rate:.2f}%'

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, investment_type):
        super().__init__(account_number, account_holder, opening_balance)
        self.investment_type = investment_type
        
    def __str__(self):
        return f'Investment Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, investment type = {self.investment_type}'

# %%
import fintech.accounts as accounts

acc1 = accounts.CurrentAccount('123', 'John', 10.05, 100.0)
acc2 = accounts.DepositAccount('345', 'John', 23.55, 0.5)
acc3 = accounts.InvestmentAccount('567', 'Phoebe', 12.45, 'high risk')

print(acc1)
print(acc2)
print(acc3)

acc1.deposit(23.45)
acc1.withdraw(12.33)
print('balance:', acc1.balance)
print('Number of Account instances created:', accounts.Account.instance_count)

try:
    print('balance:', acc1.balance)
    acc1.withdraw(300.00)
    print('balance:', acc1.balance)
except accounts.BalanceError as e:
    print('Handling Exception')
    print(e)

# %%
from abc import ABC, abstractmethod

class Account(ABC):
    instance_count = 0
    
    def __init__(self, account_number, account_holder, opening_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self._balance = opening_balance
        Account.instance_count += 1
        
    @property
    def balance(self):
        return self._balance
    
    @abstractmethod
    def deposit(self, amount):
        pass
    
    @abstractmethod
    def withdraw(self, amount):
        pass
        
    def __str__(self):
        return f'Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}'

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, overdraft_limit):
        super().__init__(account_number, account_holder, opening_balance)
        self.overdraft_limit = overdraft_limit
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        if self._balance - amount >= -self.overdraft_limit:
            super().withdraw(amount)
        else:
            raise BalanceError(self, "Withdrawal would exceed your overdraft limit")
            
    def deposit(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot deposit negative amounts")
        self._balance += amount
        
    def __str__(self):
        return f'Current Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, overdraft limit = {self.overdraft_limit:.2f}'

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, interest_rate):
        super().__init__(account_number, account_holder, opening_balance)
        self.interest_rate = interest_rate
        
    def deposit(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot deposit negative amounts")
        self._balance += amount
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        self._balance -= amount
        
    def __str__(self):
        return f'Deposit Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, interest rate = {self.interest_rate:.2f}%'

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, opening_balance, investment_type):
        super().__init__(account_number, account_holder, opening_balance)
        self.investment_type = investment_type
        
    def deposit(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot deposit negative amounts")
        self._balance += amount
        
    def withdraw(self, amount):
        if amount < 0:
            raise AmountError(self, "Cannot withdraw negative amounts")
        self._balance -= amount
        
    def __str__(self):
        return f'Investment Account[{self.account_number}] - {self.account_holder}, balance = {self._balance:.2f}, investment type = {self.investment_type}'

# %%
Convert Account as Abstract Class

# %%
from abc import ABC, abstractmethod

class Account(ABC):
    def __init__(self, account_number, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

    @abstractmethod
    def withdraw(self, amount):
        pass

    @abstractmethod
    def deposit(self, amount):
        pass

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, balance, overdraft_limit):
        super().__init__(account_number, account_holder, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if self.balance - amount >= -self.overdraft_limit:
            self.balance -= amount
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, balance, interest_rate):
        super().__init__(account_number, account_holder, balance)
        self.interest_rate = interest_rate

    def withdraw(self, amount):
        if self.balance - amount >= 0:
            self.balance -= amount
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, balance, risk_level):
        super().__init__(account_number, account_holder, balance)
        self.risk_level = risk_level

    def withdraw(self, amount):
        if self.balance - amount >= 0:
            self.balance -= amount
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

# Example usage
acc1 = CurrentAccount('123', 'John', 10.05, 100.0)
acc2 = DepositAccount('345', 'John', 23.55, 0.5)
acc3 = InvestmentAccount('567', 'Phoebe', 12.45, 'risky')

# %% [markdown]
# create history of transaction using list

# %%
from abc import ABC, abstractmethod

class Transaction:
    def __init__(self, action, amount):
        self.action = action
        self.amount = amount

    def __str__(self):
        return f"Transaction[{self.action}: {self.amount}]"

class Account(ABC):
    def __init__(self, account_number, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance
        self.transaction_history = []

    @abstractmethod
    def withdraw(self, amount):
        pass

    @abstractmethod
    def deposit(self, amount):
        pass

    def add_transaction(self, action, amount):
        transaction = Transaction(action, amount)
        self.transaction_history.append(transaction)

    def __iter__(self):
        return iter(self.transaction_history)

class CurrentAccount(Account):
    def __init__(self, account_number, account_holder, balance, overdraft_limit):
        super().__init__(account_number, account_holder, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if self.balance - amount >= -self.overdraft_limit:
            self.balance -= amount
            self.add_transaction("withdraw", amount)
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        self.add_transaction("deposit", amount)
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

class DepositAccount(Account):
    def __init__(self, account_number, account_holder, balance, interest_rate):
        super().__init__(account_number, account_holder, balance)
        self.interest_rate = interest_rate

    def withdraw(self, amount):
        if self.balance - amount >= 0:
            self.balance -= amount
            self.add_transaction("withdraw", amount)
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        self.add_transaction("deposit", amount)
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

class InvestmentAccount(Account):
    def __init__(self, account_number, account_holder, balance, risk_level):
        super().__init__(account_number, account_holder, balance)
        self.risk_level = risk_level

    def withdraw(self, amount):
        if self.balance - amount >= 0:
            self.balance -= amount
            self.add_transaction("withdraw", amount)
            print(f"Withdrawal of {amount} successful. New balance: {self.balance}")
        else:
            print("Insufficient funds for withdrawal.")

    def deposit(self, amount):
        self.balance += amount
        self.add_transaction("deposit", amount)
        print(f"Deposit of {amount} successful. New balance: {self.balance}")

# Example usage
acc1 = CurrentAccount('123', 'John', 10.05, 100.0)
acc1.deposit(10.05)
acc1.withdraw(5.0)

for transaction in acc1:
    print(transaction)
# Out:
# Deposit of 10.05 successful. New balance: 20.1
# Withdrawal of 5.0 successful. New balance: 15.100000000000001
# Transaction[deposit: 10.05]
# Transaction[withdraw: 5.0]
